# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('traffic.csv')
df
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  Rush Hour  \
# 0         NaN  288.28      0.0      0.0          40        Clouds          1
# 1         NaN  289.36      0.0      0.0          75        Clouds          0
# 2         NaN  289.58      0.0      0.0          90        Clouds          0
# 3         NaN  290.13      0.0      0.0          90        Clouds          0
# 4         NaN  291.14      0.0      0.0          75        Clouds          0
# ...       ...     ...      ...      ...         ...           ...        ...
# 48199     NaN  283.45      0.0      0.0          75        Clouds          1
# 48200     NaN  282.76      0.0      0.0          90        Clouds          0
# 48201     NaN  282.73      0.0      0.0          90  Thunderstorm          0
# 48202     NaN  282.09      0.0      0.0          90        Clouds          0
# 48203     NaN  282.12      0.0      0.0          90        Clouds          0
#
#        traffic_volume
# ...

# %%
df.shape
# Out:
# (48204, 8)

# %%
df.head(2)
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  Rush Hour  \
# 0     NaN  288.28      0.0      0.0          40       Clouds          1
# 1     NaN  289.36      0.0      0.0          75       Clouds          0
#
#    traffic_volume
# 0            5545
# 1            4516

# %%
df.tail(3)
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  Rush Hour  \
# 48201     NaN  282.73      0.0      0.0          90  Thunderstorm          0
# 48202     NaN  282.09      0.0      0.0          90        Clouds          0
# 48203     NaN  282.12      0.0      0.0          90        Clouds          0
#
#        traffic_volume
# 48201            2159
# 48202            1450
# 48203             954

# %%
df[2:6]
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  Rush Hour  \
# 2     NaN  289.58      0.0      0.0          90       Clouds          0
# 3     NaN  290.13      0.0      0.0          90       Clouds          0
# 4     NaN  291.14      0.0      0.0          75       Clouds          0
# 5     NaN  291.72      0.0      0.0           1        Clear          0
#
#    traffic_volume
# 2            4767
# 3            5026
# 4            4918
# 5            5181

# %%
df[['temp','clouds_all']]
# Out:
#          temp  clouds_all
# 0      288.28          40
# 1      289.36          75
# 2      289.58          90
# 3      290.13          90
# 4      291.14          75
# ...       ...         ...
# 48199  283.45          75
# 48200  282.76          90
# 48201  282.73          90
# 48202  282.09          90
# 48203  282.12          90
#
# [48204 rows x 2 columns]

# %%
df['temp']
# Out:
# 0        288.28
# 1        289.36
# 2        289.58
# 3        290.13
# 4        291.14
#           ...
# 48199    283.45
# 48200    282.76
# 48201    282.73
# 48202    282.09
# 48203    282.12
# Name: temp, Length: 48204, dtype: float64

# %%
#OPERATIONS ON DATAFRAME
df['temp'].max()
# Out:
# np.float64(310.07)

# %%
df['temp'].min()
# Out:
# np.float64(0.0)

# %%
df['temp'].std()
# Out:
# np.float64(13.338231912676328)

# %%
#Conditionally select data in dataframe
df[df.temp>=31]
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  Rush Hour  \
# 0         NaN  288.28      0.0      0.0          40        Clouds          1
# 1         NaN  289.36      0.0      0.0          75        Clouds          0
# 2         NaN  289.58      0.0      0.0          90        Clouds          0
# 3         NaN  290.13      0.0      0.0          90        Clouds          0
# 4         NaN  291.14      0.0      0.0          75        Clouds          0
# ...       ...     ...      ...      ...         ...           ...        ...
# 48199     NaN  283.45      0.0      0.0          75        Clouds          1
# 48200     NaN  282.76      0.0      0.0          90        Clouds          0
# 48201     NaN  282.73      0.0      0.0          90  Thunderstorm          0
# 48202     NaN  282.09      0.0      0.0          90        Clouds          0
# 48203     NaN  282.12      0.0      0.0          90        Clouds          0
#
#        traffic_volume
# ...

# %%
df[['temp','clouds_all']][df.temp == df['temp'].max()]
# Out:
#          temp  clouds_all
# 44457  310.07          75

# %%
#Set Index
df
# Out:
#       holiday    temp  rain_1h  snow_1h  clouds_all  weather_main  Rush Hour  \
# 0         NaN  288.28      0.0      0.0          40        Clouds          1
# 1         NaN  289.36      0.0      0.0          75        Clouds          0
# 2         NaN  289.58      0.0      0.0          90        Clouds          0
# 3         NaN  290.13      0.0      0.0          90        Clouds          0
# 4         NaN  291.14      0.0      0.0          75        Clouds          0
# ...       ...     ...      ...      ...         ...           ...        ...
# 48199     NaN  283.45      0.0      0.0          75        Clouds          1
# 48200     NaN  282.76      0.0      0.0          90        Clouds          0
# 48201     NaN  282.73      0.0      0.0          90  Thunderstorm          0
# 48202     NaN  282.09      0.0      0.0          90        Clouds          0
# 48203     NaN  282.12      0.0      0.0          90        Clouds          0
#
#        traffic_volume
# ...

# %%
df.set_index('temp',inplace =True)
df
# Out:
#        holiday  rain_1h  snow_1h  clouds_all  weather_main  Rush Hour  \
# temp
# 288.28     NaN      0.0      0.0          40        Clouds          1
# 289.36     NaN      0.0      0.0          75        Clouds          0
# 289.58     NaN      0.0      0.0          90        Clouds          0
# 290.13     NaN      0.0      0.0          90        Clouds          0
# 291.14     NaN      0.0      0.0          75        Clouds          0
# ...        ...      ...      ...         ...           ...        ...
# 283.45     NaN      0.0      0.0          75        Clouds          1
# 282.76     NaN      0.0      0.0          90        Clouds          0
# 282.73     NaN      0.0      0.0          90  Thunderstorm          0
# 282.09     NaN      0.0      0.0          90        Clouds          0
# 282.12     NaN      0.0      0.0          90        Clouds          0
#
#         traffic_volume
# temp
# 288.28            5545
# 289.36            4516
# 289.58            4767
# ...

# %%
df.loc[282.73]
# Out:
#        holiday  rain_1h  snow_1h  clouds_all  weather_main  Rush Hour  \
# temp
# 282.73     NaN      0.0      0.0          20        Clouds          0
# 282.73     NaN      0.0      0.0           1         Clear          0
# 282.73     NaN      0.0      0.0          75        Clouds          1
# 282.73     NaN      0.0      0.0          56        Clouds          1
# 282.73     NaN      0.0      0.0           0         Clear          0
# 282.73     NaN      0.0      0.0           1         Clear          0
# 282.73     NaN      0.0      0.0           1         Clear          0
# 282.73     NaN      0.0      0.0          90  Thunderstorm          0
#
#         traffic_volume
# temp
# 282.73            4701
# 282.73            2815
# 282.73            6085
# 282.73            6228
# 282.73             359
# 282.73            2920
# 282.73             839
# 282.73            2159

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#          temp holiday  rain_1h  snow_1h  clouds_all  weather_main  Rush Hour  \
# 0      288.28     NaN      0.0      0.0          40        Clouds          1
# 1      289.36     NaN      0.0      0.0          75        Clouds          0
# 2      289.58     NaN      0.0      0.0          90        Clouds          0
# 3      290.13     NaN      0.0      0.0          90        Clouds          0
# 4      291.14     NaN      0.0      0.0          75        Clouds          0
# ...       ...     ...      ...      ...         ...           ...        ...
# 48199  283.45     NaN      0.0      0.0          75        Clouds          1
# 48200  282.76     NaN      0.0      0.0          90        Clouds          0
# 48201  282.73     NaN      0.0      0.0          90  Thunderstorm          0
# 48202  282.09     NaN      0.0      0.0          90        Clouds          0
# 48203  282.12     NaN      0.0      0.0          90        Clouds          0
#
#        traffic_volume
# ...

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("traffic.csv")
print(df.head())
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  Rush Hour  \
# 0     NaN  288.28      0.0      0.0          40       Clouds          1
# 1     NaN  289.36      0.0      0.0          75       Clouds          0
# 2     NaN  289.58      0.0      0.0          90       Clouds          0
# 3     NaN  290.13      0.0      0.0          90       Clouds          0
# 4     NaN  291.14      0.0      0.0          75       Clouds          0
#
#    traffic_volume
# 0            5545
# 1            4516
# 2            4767
# 3            5026
# 4            4918

# %%
plt.scatter(df.temp,df.weather_main)
plt.show()

# %%
plt.scatter(df.temp,df.weather_main)
sns.set_style("dark")
plt.show()

# %%
plt.scatter(df.temp,df.weather_main)
sns.set_style("whitegrid")
sns.set_context("notebook")  
plt.show()

# %%
#Histogram
df.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  Rush Hour  \
# 0     NaN  288.28      0.0      0.0          40       Clouds          1
# 1     NaN  289.36      0.0      0.0          75       Clouds          0
# 2     NaN  289.58      0.0      0.0          90       Clouds          0
# 3     NaN  290.13      0.0      0.0          90       Clouds          0
# 4     NaN  291.14      0.0      0.0          75       Clouds          0
#
#    traffic_volume
# 0            5545
# 1            4516
# 2            4767
# 3            5026
# 4            4918

# %%
sns.displot(df['traffic_volume'],kde=False)

# %%
sns.set_context('talk')
df.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  Rush Hour  \
# 0     NaN  288.28      0.0      0.0          40       Clouds          1
# 1     NaN  289.36      0.0      0.0          75       Clouds          0
# 2     NaN  289.58      0.0      0.0          90       Clouds          0
# 3     NaN  290.13      0.0      0.0          90       Clouds          0
# 4     NaN  291.14      0.0      0.0          75       Clouds          0
#
#    traffic_volume
# 0            5545
# 1            4516
# 2            4767
# 3            5026
# 4            4918

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x='weather_main', y='traffic_volume', data=df, hue='weather_main', palette='PuRd', errorbar=None)
plt.xticks(rotation=45) 
plt.show()
# Out:
# C:\Users\Supriya\AppData\Local\Temp\ipykernel_16764\2748954689.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend().remove()  # Optional: Remove legend if not needed

# %%
# Horizontal Barplot

import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x='temp', y='weather_main', data=df, palette='PuRd', errorbar=None)  # Swap x and y for horizontal bars
plt.show()  # No need for plt.legend()
# Out:
# C:\Users\Supriya\AppData\Local\Temp\ipykernel_16764\386134273.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='temp', y='weather_main', data=df, palette='PuRd', errorbar=None)  # Swap x and y for horizontal bars

# %%
sns.set_context('paper')

sns.countplot(x='temp', hue='weather_main',data=df,palette='magma')
plt.title('Survivors')
plt.show()
# Out:
# C:\Users\Supriya\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import seaborn as sns

sns.jointplot(x='temp', y='weather_main', data=df, kind='scatter')  # or kind='hist'

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x="temp", y="weather_main", data=df)
plt.show()
